# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None

class Queue:
    def __init__(self):
        self.front=None
        self.rear=None

    def enqueue(self,data):
        new_node=Node(data)

        if self.rear is None:
            self.front=self.rear=new_node
        else:
            self.rear.next=new_node
            self.rear=new_node
        print("Element inserted successfully")

    def dequeue(self):
        if self.front is None:
            print("Queue Underflow")
        else:
            data=self.front.data
            self.front=self.front.next

        if self.front is None:
            self.rear=None
        
        print("Deleted element:",data)

    def display(self):
        if self.front is None:
            print("Queue is empty")
        else:
            current=self.front
            print("Queue elements:",end=" ")

            while current:
                print(current.data,end=" ")
                current=current.next
            
            print()

queue=Queue()

while True:
    print("\n--- Queue Menu ---")
    print("1.Enqueue")
    print("2.Dequeue")
    print("3.Display")
    print("4.Exit")
    
    choice=int(input("Enter your choice:"))

    if choice==1:
        value=int(input("Enter element:"))
        queue.enqueue(value)
    elif choice==2:
        queue.dequeue()
    elif choice==3:
        queue.display()
    elif choice==4:
        break
    else:
        print("Invalid choice")
# Out:
# --- Queue Menu ---
# 1.Enqueue
# 2.Dequeue
# 3.Display
# 4.Exit
# Enter your choice: 1
# Enter element: 21
# Element inserted successfully
#
# --- Queue Menu ---
# 1.Enqueue
# 2.Dequeue
# 3.Display
# 4.Exit
# Enter your choice: 1
# Enter element: 23
# Element inserted successfully
#
# --- Queue Menu ---
# 1.Enqueue
# 2.Dequeue
# 3.Display
# 4.Exit
# Enter your choice: 1
# Enter element: 22
# Element inserted successfully
#
# --- Queue Menu ---
# 1.Enqueue
# 2.Dequeue
# 3.Display
# 4.Exit
# Enter your choice: 1
# Enter element: 213
# Element inserted successfully
#
# --- Queue Menu ---
# 1.Enqueue
# 2.Dequeue
# 3.Display
# 4.Exit
# Enter your choice: 3
# Queue elements: 21 23 22 213
#
# --- Queue Menu ---
# 1.Enqueue
# 2.Dequeue
# 3.Display
# 4.Exit
# Enter your choice: 2
# Deleted element: 21
#
# --- Queue Menu ---
# 1.Enqueue
# 2.Dequeue
# 3.Display
# 4.Exit
# Enter your choice: 3
# Queue elements: 23 22 213
#
# --- Queue Menu ---
# 1.Enqueue
# 2.Dequeue
# 3.Display
# 4.Exit
# Enter your choice: 2
# Deleted element: 23
#
# --- Queue Menu ---
# 1.Enqueue
# 2.Dequeue
# 3.Display
# 4.Exit
# Enter your choice: 3
# Queue elements: 22 213
#
# --- Queue Menu ---
# 1.Enqueue
# 2.Dequeue
# 3.Display
# 4.Exit
# Enter your choice: 4
