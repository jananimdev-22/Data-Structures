# %%
# Stack implementation in Python with menu-driven interface

class Stack:
    def __init__(self, capacity):
        self.capacity = capacity
        self.items = []

    def push(self, item):
        if self.isFull():
            print("Stack is full! Cannot push.")
        else:
            self.items.append(item)
            print(f"Pushed: {item}")

    def pop(self):
        if self.isEmpty():
            print("Stack is empty! Cannot pop.")
        else:
            removed = self.items.pop()
            print(f"Popped: {removed}")

    def peek(self):
        if self.isEmpty():
            print("Stack is empty! Nothing to peek.")
        else:
            print(f"Top element: {self.items[-1]}")

    def isEmpty(self):
        return len(self.items) == 0

    def isFull(self):
        return len(self.items) == self.capacity

    def display(self):
        if self.isEmpty():
            print("Stack is empty.")
        else:
            print("Stack (top → bottom):", list(reversed(self.items)))


# Main program
try:
    capacity = int(input("Enter stack capacity: "))
    if capacity <= 0:
        raise ValueError("Capacity must be a positive integer.")
except ValueError as e:
    print(f"Invalid input: {e}")
    exit(1)

stack = Stack(capacity)

while True:
    print("\n--- Stack Operations ---")
    print("1. Push")
    print("2. Pop")
    print("3. Peek")
    print("4. Check if Empty")
    print("5. Check if Full")
    print("6. Display Stack")
    print("7. Exit")

    choice = input("Enter your choice (1-7): ").strip()

    if choice == "1":
        item = input("Enter item to push: ")
        stack.push(item)
    elif choice == "2":
        stack.pop()
    elif choice == "3":
        stack.peek()
    elif choice == "4":
        print("Stack is empty." if stack.isEmpty() else "Stack is not empty.")
    elif choice == "5":
        print("Stack is full." if stack.isFull() else "Stack is not full.")
    elif choice == "6":
        stack.display()
    elif choice == "7":
        print("Exiting program.")
        break
    else:
        print("Invalid choice! Please enter a number between 1 and 7.")
# Out:
# Enter stack capacity:  4
# --- Stack Operations ---
# 1. Push
# 2. Pop
# 3. Peek
# 4. Check if Empty
# 5. Check if Full
# 6. Display Stack
# 7. Exit
# Enter your choice (1-7):  4
# Stack is empty.
#
# --- Stack Operations ---
# 1. Push
# 2. Pop
# 3. Peek
# 4. Check if Empty
# 5. Check if Full
# 6. Display Stack
# 7. Exit
# Enter your choice (1-7):  1
# Enter item to push:  12,23,1,45,3,54,21
# Pushed: 12,23,1,45,3,54,21
#
# --- Stack Operations ---
# 1. Push
# 2. Pop
# 3. Peek
# 4. Check if Empty
# 5. Check if Full
# 6. Display Stack
# 7. Exit
# Enter your choice (1-7):  7
# Exiting program.

# %%
###### stack = []
capacity = int(input("Enter stack capacity: "))

while True:
    print("\n1. Push")
    print("2. Pop")
    print("3. Peek")
    print("4. Is Empty?")
    print("5. Is Full?")
    print("6. Exit")

    choice = input("Enter choice: ")

    if choice == "1":  # Push
        if len(stack) == capacity:
            print("Stack is full!")
        else:
            item = input("Enter item: ")
            stack.append(item)
            print(f"Pushed: {item}")

    elif choice == "2":  # Pop
        if not stack:
            print("Stack is empty!")
        else:
            print(f"Popped: {stack.pop()}")

    elif choice == "3":  # Peek
        if not stack:
            print("Stack is empty!")
        else:
            print(f"Top element: {stack[-1]}")

    elif choice == "4":  # Is Empty
        print("Yes" if not stack else "No")

    elif choice == "5":  # Is Full
        print("Yes" if len(stack) == capacity else "No")

    elif choice == "6":  # Exit
        break

    else:
        print("Invalid choice!")
# Out:
# Enter stack capacity:  3
# 1. Push
# 2. Pop
# 3. Peek
# 4. Is Empty?
# 5. Is Full?
# 6. Exit
# Enter choice:  1
# Enter item:  2
# Pushed: 2
#
# 1. Push
# 2. Pop
# 3. Peek
# 4. Is Empty?
# 5. Is Full?
# 6. Exit
# Enter choice:  134
# Invalid choice!
#
# 1. Push
# 2. Pop
# 3. Peek
# 4. Is Empty?
# 5. Is Full?
# 6. Exit
# Enter choice:  1
# Enter item:  32
# Pushed: 32
#
# 1. Push
# 2. Pop
# 3. Peek
# 4. Is Empty?
# 5. Is Full?
# 6. Exit
# Enter choice:  1
# Enter item:  11
# Pushed: 11
#
# 1. Push
# 2. Pop
# 3. Peek
# 4. Is Empty?
# 5. Is Full?
# 6. Exit
# Enter choice:  1
# Stack is full!
#
# 1. Push
# 2. Pop
# 3. Peek
# 4. Is Empty?
# 5. Is Full?
# 6. Exit
# Enter choice:  2
# Popped: 11
#
# 1. Push
# 2. Pop
# 3. Peek
# 4. Is Empty?
# 5. Is Full?
# 6. Exit
# Enter choice:  5
# No
#
# 1. Push
# 2. Pop
# 3. Peek
# 4. Is Empty?
# 5. Is Full?
# 6. Exit
# Enter choice:  4
# No
#
# 1. Push
# 2. Pop
# 3. Peek
# 4. Is Empty?
# 5. Is Full?
# 6. Exit
# Enter choice:  3
# Top element: 32
#
# 1. Push
# 2. Pop
# 3. Peek
# 4. Is Empty?
# 5. Is Full?
# 6. Exit
# Enter choice:  6

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class Stack:
    def __init__(self, capacity):
        self.top = None
        self.capacity = capacity
        self.size = 0

    def push(self, item):
        if self.isFull():
            print("Stack is full! Cannot push.")
            return
        new_node = Node(item)
        new_node.next = self.top
        self.top = new_node
        self.size += 1
        print(f"Pushed: {item}")

    def pop(self):
        if self.isEmpty():
            print("Stack is empty! Cannot pop.")
            return
        removed_item = self.top.data
        self.top = self.top.next
        self.size -= 1
        print(f"Popped: {removed_item}")

    def peek(self):
        if self.isEmpty():
            print("Stack is empty! Nothing to peek.")
        else:
            print(f"Top element: {self.top.data}")

    def isEmpty(self):
        return self.size == 0

    def isFull(self):
        return self.size == self.capacity

    def display(self):
        if self.isEmpty():
            print("Stack is empty.")
            return
        current = self.top
        print("Stack (top → bottom):", end=" ")
        while current:
            print(current.data, end=" ")
            current = current.next
        print("None")

try:
    capacity = int(input("Enter stack capacity: "))
    if capacity <= 0:
        raise ValueError("Capacity must be a positive integer.")
except ValueError as e:
    print(f"Invalid input: {e}")
    exit(1)

stack = Stack(capacity)

while True:
    print("\n--- Stack Operations ---")
    print("1. Push")
    print("2. Pop")
    print("3. Peek")
    print("4. Check if Empty")
    print("5. Check if Full")
    print("6. Display Stack")
    print("7. Exit")

    choice = input("Enter your choice (1-7): ").strip()

    if choice == "1":
        item = input("Enter item to push: ")
        stack.push(item)
    elif choice == "2":
        stack.pop()
    elif choice == "3":
        stack.peek()
    elif choice == "4":
        print("Stack is empty." if stack.isEmpty() else "Stack is not empty.")
    elif choice == "5":
        print("Stack is full." if stack.isFull() else "Stack is not full.")
    elif choice == "6":
        stack.display()
    elif choice == "7":
        print("Exiting program.")
        break
    else:
        print("Invalid choice! Please enter a number between 1 and 7.")
# Out:
# Enter stack capacity:  3
# --- Stack Operations ---
# 1. Push
# 2. Pop
# 3. Peek
# 4. Check if Empty
# 5. Check if Full
# 6. Display Stack
# 7. Exit
